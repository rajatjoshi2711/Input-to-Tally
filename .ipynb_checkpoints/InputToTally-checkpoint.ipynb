# %% [markdown]
# # Installation

# %%
cd E:\Clients\TOSBS\Akshay Adamuthe\CData.Python.Tally\win\Python37\64
# Out:
# E:\Clients\TOSBS\Akshay Adamuthe\CData.Python.Tally\win\Python37\64

# %%
pip install cdata_tally_connector-20.0.7654-cp37-cp37m-win_amd64.whl
# Out:
# Processing e:\clients\tosbs\akshay adamuthe\cdata.python.tally\win\python37\64\cdata_tally_connector-20.0.7654-cp37-cp37m-win_amd64.whlNote: you may need to restart the kernel to use updated packages.
# Installing collected packages: cdata-tally-connector
# Successfully installed cdata-tally-connector-20.0.7654

# %% [markdown]
# # Init

# %%
import cdata.tally as mod

# %% [markdown]
# # Queries

# %% [markdown]
# ### Display

# %%
conn = mod.connect("Url='http://localhost:9000'")
cur = conn.cursor()

cur.execute("SELECT Name, Address FROM Company")
rs = cur.fetchall()
print('Companies:')
for row in rs:
    print(row)

cur.execute("SELECT Name FROM Groups WHERE Name like '%Demo%'")
rs = cur.fetchall()
print('\nGroups:')
for row in rs:
    print(row)
    
cur.execute("SELECT Name, Bankaccholdername, Narration, StateName, ClosingBalance FROM Ledger")
rs = cur.fetchall()
print('\nLedgers:')
for row in rs:
    print(row)

cur.execute("SELECT Name, CreditTotals, ClosingBalance FROM VoucherCostCategory")
rs = cur.fetchall()
print('\nLedgers:')
for row in rs:
    print(row)
# Out:
# Companies:
# ('Demo_Company', '')
#
# Groups:
# ('Demo_group')
#
# Ledgers:
# ('Cash', '', '', '', '')
# ('Debtor1', '', '', '', '-516.00')
# ('Profit & Loss A/c', '', '', '', '516.00')
# ('Sales', '', '', '', '516.00')
#
# Ledgers:
# ('Primary Cost Category', '', '')

# %% [markdown]
# ### List of all tables and columns inside them

# %%
#List of all tables
cur.execute("SELECT TableName FROM sys_tables")
rs = cur.fetchall()
print('\nAll Tables:')
for row in rs:
    print(str(row[0]))
# Out:
# All Tables:
# AdjustmentClassification
# AllAdjClassification
# AllCostCentre
# AllTaxClassification
# AttendanceTypes
# BankLedgerVouchers
# CashLedgerVouchers
# CategoryAnalysis
# CMPTallyNetFeature
# CMPTaxAuditFeatures
# CollecteeType
# Company
# CompanyFeatures
# CompanyOperations
# CompanyOperationsAccts
# CompanyOperationsInv
# CompanyOperationsStat
# CompanyVouchers
# CostCategory
# CostCentreBreakUp
# DeducteeType
# Employees
# ExciseDutyClassification
# ExciseDutyClassificationList
# ExciseMfgrExcisableItemList
# FBTAssesseeType
# FBTCategory
# Godown
# GratuityPayrollCategories
# Groups
# GSTClassification
# GSTExtractVoucherType
# GSTRCAdvPymtListofLedgers
# GSTRCAdvPymtListofStockItems
# GSTRCAdvPymtRevCharListofLedgers
# GSTRCAdvPymtRevCharListofStockItems
# ImporterStockableGodown
# IncomeTaxClassificationList
# IncomeTaxSlabList
# ITAdvanceTaxEmployeeColl
# ITChapterVIAInvesmtsEmpDispColl
# ITChapterVIAOthersEmpDispColl
# ITComputationEmpDispColl
# ITDefineExemptionEmpDispColl
# ItemMovementAnalysis
# ITEmpOtherIncomeColl
# ITEmpReleifColl
# ITOtherSalaryTDSColl
# ITOverrideEmpDispColl
# ITPrevEmployerTaxColl
# ITPrevEmplyrIncomeDispColl
# ITR1EmpDispColl
# ITSalaryProjectEmpColl
# ITSelfAssmntTaxEmployeeColl
# ITSingleEmpPerquisitesDispColl
# JCGodownSummary
# JOBStockableGodown
# LBTClassification
# LBTClassificationMapping
# LBTClassificationMultiConfig
# Ledger
# LedgerCostBreakUp
# LedgerInterest
# LedgerOutstandings
# LedgerUnderBankAccGroup
# LedgerUnderBankGroups
# LedgerUnderCENVATGroup
# LedgerUnderExciseDutyGroup
# LedgerUnderExpensesGroup
# LedgerUnderExpGroup
# LedgerUnderMGroup
# LedgerUnderMGroupForGST
# LedgerUnderMGroupForGVAT
# LedgerUnderPartyCrDrGroup
# LedgerUnderPartyGroup
# LedgerUnderSTXDutyGroup
# LedgerUnderTCSDutyGroup
# LedgerUnderTCSParty
# LedgerUnderTCSPartyGrp
# LedgerUnderTDSDutyGroup
# LedgerUnderVATDutyGroup
# LedgerVouchers
# LedUnderPurcExpGroup
# LedUnderSalesIncGroup
# LedWithVATApplicable
# ListofAllLedgers
# ListofAttendanceTypes
# ListofClassifications
# ListofCostCategories
# ListofEmployeeCategories
# ListofGodowns
# ListofGSTPartyLedgers
# LISTofGSTRCPartyLedgers
# ListofLedgers
# ListofPayHeads
# ListofPurcTaxStockItems
# ListOfSTLedgers
# ListofStockCategories
# ListofStockGroups
# ListofStockItems
# ListofUserDefClasfn
# MfgrStockableGodown
# MfgrStockableGodownTop
# MonthlyLedger
# MonthlyLedgerExtractBrowser
# MonthlyTCSLedger
# MonthlyTDSLedger
# MovementAnalysis
# MultiCostCategory
# MultiEmpCategory
# MultiGodown
# MultiStockCategory
# MultiStockGroup
# MultiStockItem
# MultiVoucherType
# NonRevenueCategory
# PayHead
# PayrollCategories
# PayrollVchCategories
# PayrollVoucherTypes
# PFForm10Employees
# PFForm10ExportEmployees
# PFForm5Employees
# PFForm5ExportEmployees
# POStockCategory
# POStockGroup
# POStockItem
# PriceList
# PRSalWagePymtEmpColl
# PTComputation
# PTComputationExtract
# PTComputationMthly
# PTComputationMthlyExtract
# Report_BalanceSheet
# Report_BankGroupSummary
# Report_BillsPayable
# Report_BillsReceivable
# Report_GodownSummary
# Report_GroupOutstandings
# Report_GroupSummary
# Report_GroupVouchers
# Report_ItemMonthlySummary
# Report_LedgerOutstandings
# Report_LedgerVouchers
# Report_NegativeLedger
# Report_NegativeStock
# Report_ProfitAndLoss
# Report_RatioAnalysis
# Report_Statistics
# Report_StockGroupSummary
# Report_StockItemSummary
# Report_StockVouchers
# Report_TrialBalance
# Report_VoucherRegister
# SalaryEmployeesColl
# SASalWagePymtEmpColl
# ServiceTaxCategory
# setreorder
# SOStockCategory
# SOStockGroup
# SOStockItem
# StatCompanyOperations
# State
# StateAndCountry
# STCategory
# StockableDealerGodown
# StockableExciseMfgrGodown
# StockableGodown
# StockableManufacturerGodown
# StockableTraderGodown
# StockCategory
# StockGroup
# StockItem
# STXBillCategoryList
# STXBillPartyList
# STXCategory
# STXCategoryMaster
# STXCatTrTemp
# STXInActCategoryMaster
# STXInputCrCategoryList
# STXInputCrPartyList
# STXLedger
# STXLedgerUnderPartyCrDrGroup
# STXLedgerUnderServGroup
# STXMigBillsCollection
# STXMigBillsCollection1
# STXPartyTrTemp
# STXPyblBillCategory
# STXPyblBillListOfParty
# STXPyblRecptCategory
# STXPyblRecptParty
# TariffClassification
# TaxClassification
# TaxUnit
# TCSLedgerOutstandings
# TCSNOPRate
# TCSRate
# TCSRatesForLedMst
# TDSCategoryOutstandings
# TDSLedgerOutstandings
# TDSNOPRate
# TDSPartyOutstandings
# TDSRate
# TDSRatesForLedMst
# TDSReconcileLedgers
# TNetSingleLedger
# TNetTDSExpenseLedger
# TransferVchStockJrnl
# UniqueStockItem
# VCHStockItem
# VCHTariffClassification
# VoucherCostCategory
# VoucherType
# VoucherTypePSR

# %%
#List of all tables along with columns in them
cur.execute("SELECT TableName FROM sys_tables")
rs = cur.fetchall()
print('\nAll Tables:')
for row in rs:
    print('\n')
    print(str(row[0]))
    cur.execute("Select ColumnName FROM sys_tablecolumns WHERE TableName = '" + str(row[0]) + "'")
    rs2 = cur.fetchall()
    print(">> Columns in " + str(row[0]) + ":")
    for row2 in rs2:
        print(str(row2[0]))
# Out:
# All Tables:
#
#
# AdjustmentClassification
# >> Columns in AdjustmentClassification:
# Name
# GUID
# VATDealerType
# MailingName
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# TaxType
# PreviousName
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# MarkforDeletion
# IsCompositeClassification
# SortPosition
# AlterID
# RemoteAlterID
#
#
# AllAdjClassification
# >> Columns in AllAdjClassification:
# Name
# GUID
# VATDealerType
# MailingName
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# TaxType
# PreviousName
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# MarkforDeletion
# IsCompositeClassification
# SortPosition
# AlterID
# RemoteAlterID
#
#
# AllCostCentre
# >> Columns in AllCostCentre:
# ActiveFrom
# ActiveTo
# DateOfBirth
# DateOfJoin
# DeactivationDate
# VisaExpiryDate
# ContractStartDate
# ContractExpiryDate
# PassportExpiryDate
# PFJoiningDate
# PFRelievingDate
# IdentityExpiryDate
# Name
# Address
# GUID
# Parent
# Category
# MailingName
# MobileNumber
# MICRCode
# IFSCode
# Narration
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# BankDetails
# BankDetailsBankID
# Function
# Location
# Designation
# PFAccountNumber
# PANNumber
# ESINumber
# PassportDetails
# Gender
# BloodGroup
# FatherName
# ContactNumbers
# EmailID
# BankAccountNumber
# BankBranch
# VisaNumber
# WorkPermitNumber
# CountryOfIssue
# SpouseName
# FPFAccountNumber
# ReasonsForLeaving
# ESIDispensaryName
# EmpDisplayName
# IdentityNumber
# PRAccountNumber
# AadharNumber
# UANNumber
# RevenueLedForOpBal
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# AffectsStock
# ForPayroll
# ForJobCosting
# IsEmployeeGroup
# SortPosition
# AlterID
# RemoteAlterID
# DefaultLanguage
# CstCatName
# Category
#
#
# AllTaxClassification
# >> Columns in AllTaxClassification:
# ActiveFrom
# ActiveTo
# Name
# GUID
# MailingName
# StatType
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# TaxType
# SubTaxType
# PreviousName
# StatNatureName
# ClassMstType
# PartyOrgType
# BusinessNature
# GoodsType
# GoodsNature
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsInvDetailsEnable
# IsActive
# MarkforDeletion
# ClassificationIsSales
# IsCompositeClassification
# SortPosition
# AlterID
# RemoteAlterID
# RateofVAT
#
#
# AttendanceTypes
# >> Columns in AttendanceTypes:
# ActiveFrom
# ActiveTo
# Name
# GUID
# Parent
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# BaseUnits
# DisplayName
# AttendanceProductionType
# AttendancePeriod
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# ShowInReport
# SortPosition
# AlterID
# RemoteAlterID
#
#
# BankLedgerVouchers
# >> Columns in BankLedgerVouchers:
# StartingFrom
# STRegDate
# LBTRegnDate
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# CreatedDate
# AlteredOn
# VATApplicableDate
# ExciseRegistrationDate
# PANApplicableFrom
# PayInsRunningFileDate
# VATTaxExemptionDate
# Name
# Address
# GUID
# CurrencyName
# EMail
# PriorStateName
# PINCode
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# VATTINNumber
# CountryName
# ExciseRange
# ExciseDivision
# ExciseCommissionerate
# LBTRegnNo
# LBTZone
# ExportImportCode
# GSTRegistrationType
# VATDealerType
# StateName
# PriceLevel
# UploadLastRefresh
# Parent
# MailingName
# SamplingMethod
# SamplingStrOneFactor
# IFSCode
# Narration
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# GrpDebitParent
# GrpCreditParent
# SysDebitParent
# SysCreditParent
# TDSApplicable
# TCSApplicable
# GSTApplicable
# CreatedBy
# AlteredBy
# TaxClassificationName
# TaxType
# BillCreditPeriod
# BankDetails
# BankBranchName
# BankBSRCode
# DeducteeType
# BusinessType
# TypeOfNotification
# MSMERegNumber
# CountryofResidence
# RelatedPartyId
# RelPartyIssuingAuthority
# ImporterExporterCode
# EmailCC
# Description
# LedAddlAllocType
# TransporterId
# LedgerPhone
# LedgerFax
# LedgerContact
# LedgerMobile
# RelationType
# MailingNameNative
# AddressNative
# StateNameNative
# CountryNameNative
# BasicTypeOfDuty
# GSTType
# ExemptionType
# AppropriateFor
# SubTaxType
# STXNatureOfParty
# NameOnPAN
# UsedForTaxType
# eCommMerchantID
# PartyGSTIN
# GSTDutyHead
# GSTAppropriateTo
# GSTTypeofSupply
# GSTNatureofSupply
# CessValuationMethod
# PartyOldGSTIN
# LedStateName
# PayType
# PayslipName
# AttendanceType
# LeaveType
# CalculationPeriod
# RoundingMethod
# ComputationType
# CalculationType
# PayStatType
# ProfessionalTaxNumber
# UserDefinedCalenderType
# ITNature
# ITComponent
# NotificationNumber
# RegistrationNumber
# ServiceCategory
# AbatementNotificationNo
# STXDutyHead
# STXClassification
# NotificationSlNo
# ServiceTaxApplicable
# ExciseLedgerClassification
# ExciseRegistrationNumber
# ExciseAccountHead
# ExciseDutyType
# ExciseDutyHeadCode
# ExciseAllocType
# ExciseDutyHead
# NatureOfSales
# ExciseNotificationNo
# ExciseImportsRegistartionNo
# ExciseApplicability
# ExciseTypeofBranch
# ExciseDefaultRemoval
# ExciseNotificationSlNo
# TypeOfTariff
# ExciseRegNo
# ExciseNatureofPurchase
# TDSDeducteeTypeMst
# TDSRateName
# TDSDeducteeSectionNumber
# PANStatus
# DeducteeReference
# TDSDeducteeType
# ITExemptApplicable
# TaxIdentificationNo
# LedgerFBTCategory
# BranchCode
# ClientCode
# BankingConfigBank
# BankingConfigBankID
# BankAccHolderName
# UseForPOSType
# PaymentGateway
# TypeOfInterestOn
# BankConfigIFSC
# BankConfigMICR
# BankConfigShortCode
# PymtInstoutputName
# ProductCodeType
# SalaryPymtProductCode
# OtherPymtProductCode
# PaymentInstLocation
# EncrptionLocation
# NewIMFLocation
# ImportedIMFLocation
# BankNewStatements
# BankImportedStatements
# BankMICR
# CorporateUserNoECS
# CorporateUserNoACH
# CorporateUserName
# BankUserLoginID
# IMFName
# PayInsBatchName
# LastUsedBatchName
# PayInsFileNumPeriod
# EncryptedBy
# EncryptedId
# ISOCurrencyCode
# BankCapsuleID
# SalesTaxCessApplicable
# BankIBAN
# VATTaxExemptionNature
# VATTaxExemptionNumber
# VATApplicable
# PartyBusinessType
# PartyBusinessStyle
# SwiftCode
# IsBillWiseOn
# IsCostCentresOn
# IsInterestOn
# AllowinMobile
# IsCostTrackingOn
# IsBeneficiaryCodeOn
# PLasIncomeExpense
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsCondensed
# AffectsStock
# IsRateInclusiveVAT
# ForPayroll
# IsABCEnabled
# IsCreditDaysChkOn
# InterestonBillwise
# OverrideInterest
# OverrideAdvInterest
# UseForVAT
# IgnoreTDSExempt
# IsTCSApplicable
# IsTDSApplicable
# IsFBTApplicable
# IsGSTApplicable
# IsExciseApplicable
# IsTDSExpense
# IsEDLIApplicable
# IsRelatedParty
# UseForESIEligibility
# IsInterestInclLastDay
# AppropriateTaxValue
# IsBehaveAsDuty
# InterestInclDayOfAddition
# InterestInclDayOfDeduction
# IsOthTerritoryAssessee
# OverRideCreditLimit
# IsAgainstFormC
# IsChequePrintingEnabled
# IsPayUpLoad
# IsPayBatchOnlySAL
# IsBNFCodeSupported
# AllowExportWithErrors
# ConsiderPurchaseforExport
# IsTransporter
# UseForNotionalITC
# IseCommOperator
# ShowinPayslip
# UseForGratuity
# IsTDSProjected
# ForServiceTax
# IsInputCredit
# IsExempted
# IsAbatementApplicable
# IsSTXParty
# IsSTXNonRealizedType
# IsUsedForCVD
# LedBelongsToNonTaxable
# IsExciseMerchantExporter
# IsPartyExempted
# IsSEZParty
# TDSDeducteeIsSpecialRate
# IseChequeSupported
# IseDDSupported
# HaseChequeDeliveryMode
# HaseChequeDeliveryTo
# HaseChequePrintLocation
# HaseChequePayableLocation
# HaseChequeBankLocation
# HaseDDDeliveryMode
# HaseDDDeliveryTo
# HaseDDPrintLocation
# HaseDDPayableLocation
# HaseDDBankLocation
# IsEBankingEnabled
# IsExportFileEncrypted
# IsBatchEnabled
# IsProductCodeBased
# HaseDDCity
# HaseChequeCity
# IsFileNameFormatSupported
# HasClientCode
# PayInsIsBatchApplicable
# PayInsIsFileNumApp
# IsSalaryTransGroupedForBRS
# IseBankingSupported
# IsSCBUAE
# IsBankStatusApp
# IsSalaryGrouped
# UseForPurchaseTax
# Audited
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# AlterID
# RemoteAlterID
# DefaultLanguage
# OldAuditEntryIds
# RateOfTaxCalculation
# GratuityMonthDays
# GratuityLimitMonths
# CalculationBasis
# RoundingLimit
# AbatementPercentage
# TDSDeducteeSpecialRate
# BeneficiaryCodeMaxLength
# eChequePrintLocationVersion
# eChequePayableLocationVersion
# eDDPrintLocationVersion
# eDDPayableLocationVersion
# PayInsRunningFileNum
# TransactionTypeVersion
# PayInsFileNumLength
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# OpeningBalance
# CreditLimit
# GratuityLimitAmount
# ODLimit
# ClosingBalance
# Address1
# Address2
# Address3
# Address4
# Address5
# PrimaryGroup
# OverdueBills
# OnAccountValue
# CashInFlow
# CashOutFlow
# Performance
# DrInterest
# CrInterest
# LastInterestDate
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# CashLedgerVouchers
# >> Columns in CashLedgerVouchers:
# Name
# StartingFrom
# STRegDate
# LBTRegnDate
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# CreatedDate
# AlteredOn
# VATApplicableDate
# ExciseRegistrationDate
# PANApplicableFrom
# PayInsRunningFileDate
# VATTaxExemptionDate
# Guid
# CurrencyName
# Email
# PriorStateName
# PINCode
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# VATTINNumber
# CountryName
# ExciseRange
# ExciseDivision
# ExciseCommissionerate
# LBTRegnNo
# LBTZone
# ExportImportCode
# GSTRegistrationType
# VATDealerType
# StateName
# PriceLevel
# UploadLastRefresh
# Parent
# SamplingMethod
# SamplingStrOneFactor
# IFSCode
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# GrpDebitParent
# GrpCreditParent
# SysDebitParent
# SysCreditParent
# TDSApplicable
# TCSApplicable
# GSTApplicable
# CreatedBy
# AlteredBy
# TaxClassificationName
# TaxType
# BillCreditPeriod
# BankDetails
# BankBranchName
# BankBSRCode
# DeducteeType
# BusinessType
# TypeOfNotification
# MSMERegNumber
# CountryofResidence
# RelatedPartyId
# RelPartyIssuingAuthority
# ImporterExporterCode
# EMailCC
# Description
# LedAddlAllocType
# TransporterId
# LedgerPhone
# LedgerFax
# LedgerContact
# LedgerMobile
# RelationType
# MailingNameNative
# StateNameNative
# CountryNameNative
# BasicTypeOfDuty
# GSTType
# ExemptionType
# AppropriateFor
# SubTaxType
# STXNatureOfParty
# NameOnPAN
# UsedForTaxType
# eCommMerchantID
# PartyGSTIN
# GSTDutyHead
# GSTAppropriateTo
# GSTTypeofSupply
# GSTNatureofSupply
# CessValuationMethod
# PartyOldGSTIN
# LedStateName
# PayType
# PayslipName
# AttendanceType
# LeaveType
# CalculationPeriod
# RoundingMethod
# ComputationType
# CalculationType
# PayStatType
# ProfessionalTaxNumber
# UserDefinedCalenderType
# ITNature
# ITComponent
# NotificationNumber
# RegistrationNumber
# ServiceCategory
# AbatementNotificationNo
# STXDutyHead
# STXClassification
# NotificationSlNo
# ServiceTaxApplicable
# ExciseLedgerClassification
# ExciseRegistrationNumber
# ExciseAccountHead
# ExciseDutyType
# ExciseDutyHeadCode
# ExciseAllocType
# ExciseDutyHead
# NatureOfSales
# ExciseNotificationNo
# ExciseImportsRegistartionNo
# ExciseApplicability
# ExciseTypeofBranch
# ExciseDefaultRemoval
# ExciseNotificationSlNo
# TypeOfTariff
# ExciseRegNo
# ExciseNatureofPurchase
# TDSDeducteeTypeMst
# TdsRateName
# TDSDeducteeSectionNumber
# PANStatus
# DeducteeReference
# TDSDeducteeType
# ITExemptApplicable
# TaxIdentificationNo
# LedgerFBTCategory
# BranchCode
# ClientCode
# BankingConfigBank
# BankingConfigBankID
# BankAccHolderName
# UseForPOSType
# PaymentGateway
# TypeOfInterestOn
# BankConfigIFSC
# BankConfigMICR
# BankConfigShortCode
# PymtInstoutputName
# ProductCodeType
# SalaryPymtProductCode
# OtherPymtProductCode
# PaymentInstLocation
# EncrptionLocation
# NewIMFLocation
# ImportedIMFLocation
# BankNewStatements
# BankImportedStatements
# BankMICR
# CorporateUserNoECS
# CorporateUserNoACH
# CorporateUserName
# IMFName
# PayInsBatchName
# LastUsedBatchName
# PayInsFileNumPeriod
# EncryptedBy
# EncryptedId
# ISOCurrencyCode
# BankCapsuleID
# SalesTaxCessApplicable
# BankIBAN
# VATTaxExemptionNature
# VATTaxExemptionNumber
# VATApplicable
# PartyBusinessType
# PartyBusinessStyle
# SwiftCode
# IsBillWiseOn
# IsCostCentresOn
# IsInterestOn
# AllowinMobile
# IsCostTrackingOn
# IsBeneficiaryCodeOn
# PLasIncomeExpense
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsCondensed
# AffectsStock
# IsRateInclusiveVAT
# ForPayroll
# IsABCEnabled
# IsCreditDaysChkOn
# InterestonBillwise
# OverrideInterest
# OverrideAdvInterest
# UseForVAT
# IgnoreTDSExempt
# IsTCSApplicable
# IsTDSApplicable
# IsFBTApplicable
# IsGSTApplicable
# IsExciseApplicable
# IsTDSExpense
# IsEDLIApplicable
# IsRelatedParty
# UseForESIEligibility
# IsInterestInclLastDay
# AppropriateTaxValue
# IsBehaveAsDuty
# InterestInclDayOfAddition
# InterestInclDayOfDeduction
# IsOthTerritoryAssessee
# OverRideCreditLimit
# IsAgainstFormC
# IsChequePrintingEnabled
# IsPayUpLoad
# IsPayBatchOnlySAL
# IsBNFCodeSupported
# AllowExportWithErrors
# ConsiderPurchaseforExport
# IsTransporter
# UseForNotionalITC
# IseCommOperator
# ShowinPayslip
# UseForGratuity
# IsTDSProjected
# ForServiceTax
# IsInputCredit
# IsExempted
# IsAbatementApplicable
# IsSTXParty
# IsSTXNonRealizedType
# IsUsedForCVD
# LedBelongsToNonTaxable
# IsExciseMerchantExporter
# IsPartyExempted
# IsSEZParty
# TDSDeducteeIsSpecialRate
# IseChequeSupported
# IseDDSupported
# HaseChequeDeliveryMode
# HaseChequeDeliveryTo
# HaseChequePrintLocation
# HaseChequePayableLocation
# HaseChequeBankLocation
# HaseDDDeliveryMode
# HaseDDDeliveryTo
# HaseDDPrintLocation
# HaseDDPayableLocation
# HaseDDBankLocation
# IseBankingEnabled
# IsExportFileEncrypted
# IsBatchEnabled
# IsProductCodeBased
# HaseDDCity
# HaseChequeCity
# IsFileNameFormatSupported
# HasClientCode
# PayInsIsBatchApplicable
# PayInsIsFileNumApp
# IsSalaryTransGroupedForBRS
# IseBankingSupported
# IsSCBUAE
# IsBankStatusApp
# IsSalaryGrouped
# UseForPurchaseTax
# Audited
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# Alterid
# RemoteAlterID
# DefaultLanguage
# RateofTaxCalculation
# GratuityMonthDays
# GratuityLimitMonths
# CalculationBasis
# RoundingLimit
# AbatementPercentage
# TDSDeducteeSpecialRate
# BeneficiaryCodeMaxLength
# eChequePrintLocationVersion
# eChequePayableLocationVersion
# eDDPrintLocationVersion
# eDDPayableLocationVersion
# PayInsRunningFileNum
# TransactionTypeVersion
# PayInsFileNumLength
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# OpeningBalance
# CreditLimit
# GratuityLimitAmount
# ODLimit
# tempGSTCGSTRate
# tempGSTSGSTRate
# tempGSTIGSTRate
# tempGSTStateCessRate
# tempIsVATfieldsEdited
# tempApplDate
# tempClassification
# tempNature
# tempPartyEntity
# tempBusinessNature
# tempVATRate
# tempAddlTax
# tempCessOnVat
# tempTaxType
# tempMajorCommodityName
# tempCommodityName
# tempCommodityCode
# tempSubCommodityCode
# tempUOM
# tempTypeofGoods
# tempTradeName
# tempGoodsNature
# tempSchedule
# tempScheduleslNo
# tempIsInvDetailsEnable
# tempLocalVATRate
# tempValuationType
# tempIsCalcOnQty
# tempIsSaletoLocalCitizen
# LEDIsTDSApplicableCurrLiab
# IsProductCodeEdited
# PartyoldTempGSTIN
# Address
# MailingName
# TargetRemoteId
# AddressNative
# BankUserLoginID
# OldAuditEntryIds
# ClosingBalance
# Address1
# Address2
# Address3
# Address4
# Address5
# PrimaryGroup
# OverdueBills
# OnAccountValue
# CashInFlow
# CashOutFlow
# Performance
# DrInterest
# CrInterest
# LastInterestDate
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# CategoryAnalysis
# >> Columns in CategoryAnalysis:
# ActiveFrom
# ActiveTo
# Name
# GUID
# Parent
# Narration
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# SortPosition
# AlterID
# RemoteAlterID
# OpeningBalance
# ClosingBalance
# CreditTotals
# DebitTotals
# OpeningValue
# ClosingValue
# InwardValue
# OutwardValue
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# CMPTallyNetFeature
# >> Columns in CMPTallyNetFeature:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CMPTaxAuditFeatures
# >> Columns in CMPTaxAuditFeatures:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CollecteeType
# >> Columns in CollecteeType:
# ActiveFrom
# ActiveTo
# Name
# GUID
# DeducteeStatus
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# PreviousName
# DeducteeResidentialStatus
# ForModule
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsActive
# MarkforDeletion
# SortPosition
# AlterID
# RemoteAlterID
#
#
# Company
# >> Columns in Company:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CompanyFeatures
# >> Columns in CompanyFeatures:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CompanyOperations
# >> Columns in CompanyOperations:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CompanyOperationsAccts
# >> Columns in CompanyOperationsAccts:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# CompositeApplicableDate
# VATRegDate
# DeactivateExciseFrom
# STRegDate
# DeactivateServiceTaxFrom
# LBTRegnDate
# DeactivateVATFrom
# CSTApplDate
# GSTApplicableDate
# AuditedUpto
# FIFOApplicableFrom
# ReturnsStartFrom
# Name
# BasicCompanyFormalName
# Guid
# Email
# PriorStateName
# PINCode
# PhoneNumber
# CMPEmployerId
# FaxNumber
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# TANumber
# VATTINNumber
# CompositeTIN
# EECDebtors
# EECCreditors
# CountryName
# VATPymtPeriod
# CSTPymtPeriod
# STPymtPeriod
# TDSPymtPeriod
# TCSPymtPeriod
# PFPymtPeriod
# PTPymtPeriod
# ESIPymtPeriod
# FBTPymtPeriod
# FBTYearEndPymtPeriod
# ITDeductorWard
# ITDeductorRespPersonName
# ITDeductorRespPersonFatherName
# ITDeductorRespPersonDesig
# TANRegNo
# VATFilingPeriodicity
# ITDeductorBranch
# ExciseRegn
# ExciseRange
# ExciseRangeAddress
# ExciseDivision
# ExciseDivisionAddress
# CMPIECCode
# ExciseAssesseeType
# ExciseCommissionerate
# ExciseRangeCode
# ExciseDivisionCode
# ExciseFocalBankCode
# ExciseFocalBankName
# ExciseFocalBankAddr
# STRegNumber
# STAssesseeCode
# STOrgType
# STMajorService
# STDivisionCode
# STDivisionName
# STRangeCode
# STRangeName
# STCommrtCode
# STCommrtName
# STFocalBankCode
# STFocalBankName
# STFocalBankAddr
# STAdjExpenses
# STLargeTaxPayerUnit
# STPremisesCodeNo
# ServiceTaxLiabilityType
# RevChargeType
# DeductorWard
# DeductorStatus
# DeductorRespPersonName
# DeductorRespPersonDesig
# DeductorRespPersonFatherName
# HeadOfficeTANumber
# TDSDeductorType
# PersonResponsiblePAN
# PersonResponsibleFlatNo
# PersonResponsiblePremises
# PersonResponsibleRoad
# PersonResponsibleArea
# PersonResponsibleCity
# PriorPersonResponsibleState
# PersonResponsiblePincode
# PersonResponsibleMobile
# PersonResponsibleSTDCode
# PersonResponsiblePhone
# PersonResponsibleEMail
# PersonResponsibleAltSTDCode
# PersonResponsibleAltPhone
# PersonResponsibleAltEMail
# PersonResponsibleAltMobile
# DeductorResponsibleAltSTDCode
# DeductorResponsibleAltPhone
# DeductorResponsibleAltEMail
# DeductorResponsibleAltMobile
# ITDeductorRespPersonPAN
# DeductorBranch
# CompanyFBTAssesseeType
# CompanyFBTAssesseeCategory
# CMPPFCode
# CMPPFAccountGroupCode
# CMPPFSecurityCode
# CMPESICode
# CMPESIBranchOffice
# CMPESIWorkingDays
# XBRLCIN
# XBRLIndustryType
# LBTRegnNo
# LBTZone
# EconomicActivityCode
# AuthorisedPersonName
# AuthorisedPersonDesignation
# AuthorisedPlace
# CircleSector
# CircleDivision
# ExportImportCode
# TaxAuthorisedPerson
# CircleWard
# VATReturnForm
# GSTRegistrationNumber
# GSTRegistrationType
# CmpTypeOfSupply
# CompanyNameNative
# CompanyEmirateNative
# CompanyCountryNative
# VATDealerType
# ConnectName
# SMSShortCode
# SMSPrefix
# CompanyContactPerson
# CompanyContactNumber
# CompanySMSName
# Logopath
# StateName
# PersonResponsibleState
# CompanyChequeName
# TDSNatureOfPayment
# TCSNatureofGood
# CRNumber
# BranchCRNumber
# ShowBankDetails
# GenerateBatchesOn
# UploadLastRefresh
# AdminEmailId
# IsAggregate
# IndianVat
# IsVATRegdDealer
# IsVATCompositeDealer
# IsDaywiseCashAggregate
# ITDeductorType
# IsAuditWorkingPaperOn
# IsAuditCategoryOn
# IsRoundOffExceOn
# IsCSTWithAddlTax
# IsSalesTaxCessOn
# IsExciseClassificationOn
# STIsSTLargeTaxPayer
# STXIsRoundOffApplicable
# ServiceTaxIsSEZ
# STIsMultiUnit
# STUserDefinedClass
# STIsInputServDistributor
# IsSTStockItemOn
# IsReverseApplicable
# STIsMonthlyReturns
# DeductorType
# IgnoreITExemption
# IgnoreTCSITExemption
# IsTDSStockItemOn
# IsFBTSurchargeApplicable
# XBRLIsConsolidatedRepType
# IsLBTOn
# IsVATClassOn
# IsMRPOn
# IsRevisedAnnexureOn
# EnableVATOnItemRate
# EnableVATOnQuantity
# IsInZRBasicServices
# IsDesignatedZone
# STMaintainSepAccForExempt
# IsDeviceDetailsReq
# CMPIsUnderNPVScheme
# IsSecurityOn
# IsAccountingOn
# IsInventoryOn
# IsIntegrated
# IsBillWiseOn
# IsAllBillWiseOn
# IsCostCentresOn
# prevIsCostCategoryOn
# prevIsStockCategoryOn
# IsBatchWiseOn
# IsPerishableOn
# prevIsMultiGodownOn
# prevIsMultiCurrencyOn
# IsInvoicingOn
# prevIsRevJrnlOn
# IsRemindersOn
# prevIsDCNoteOn
# prevIsRejectionOn
# prevIsTrackingOn
# IsExciseOn
# IsChqPrintingOn
# DiffActualQty
# UseZeroEntries
# AddlAmount
# IsTallyAuditOn
# prevIsBudgetsOn
# IsPayrollOn
# IsTDSOn
# IsServiceTaxOn
# IsJobCostingOn
# IsTCSOn
# IsExciseReportsOn
# IsCompositeDealer
# IsBOMOn
# prevIsSalesOrdersOn
# prevIsPurcOrdersOn
# IsDiscountsOn
# CNoteAsInvoice
# UKVATReturns
# UsePriceLevels
# IsInterestOn
# IsAdvInterestOn
# PurcAsInvoice
# prevUseAutoCost
# DNoteAsInvoice
# prevPLasIncomeExpense
# AllowinMobile
# IsIndentOn
# IsFBTOn
# IsExciseMfgrTraderOn
# IsSalesTaxOn
# IsPayrollStatOn
# ConnectCompany
# ConnectCompanyOnLoad
# IsEntryTaxApplicable
# RevenueLedForOpBal
# EnableSMSAccess
# IsRcptsPymtsOn
# IsLogoEnabled
# IsXBRLOn
# IsProprietorship
# IsYearWise
# IsCmpLTUOn
# IsGSTOn
# IsGSTClassifOn
# DenyConnectCompanyToBPS
# PromptOnConnect
# TCSforOtherGoods
# IsConnectOnLoadDisabled
# IsDisallowInEduMode
# IsMultiAddressOn
# IsEbankingOn
# IsJobWorkOn
# prevIsMaterialTransferOn
# IsCostTrackingOn
# EnablePwdPolicy
# RestrictPwdReuse
# ResetPwdOnFirstLogin
# AllowPwdReset
# NotifyOfExpiry
# IsDefPwdPolicyAltered
# IsBankingVchMigrated
# IsBeneficiaryCodeOn
# IsTransferModeOn
# IsBankingforCCOn
# IsImpBankDetailsOn
# IsApprovalOn
# IsExportOnVchCreate
# IsExportWithErrors
# IsResetBankStatus
# IsISOCurrencyApplicable
# IsIgnoreWithWarnings
# IsFIFOApplied
# IsTrackVouchersOn
# ResetTrackedChanges
# CompanyNumber
# StatutoryVersion
# VATPymtDueDate
# CSTPymtDueDate
# STPymtDueDate
# TDSPymtDueDate
# TCSPymtDueDate
# PFPymtDueDate
# PTPymtDueDate
# ESIPymtDueDate
# FBTPymtDueDate
# FBTYearEndPymtDueDate
# STCrAdjPercent
# CmpTaxAmountTolerence
# PwdLength
# LettersInPwd
# NumeralsInPwd
# SpclCharsInPwd
# PwdHistory
# PwdExpiry
# ExpiryNotifPeriod
# NACHVersion
# MaxCashValue
# MinCashValue
# CMPESIEligibleAmount
# RTGSLimit
# Address
# CompanyAddressNative
# PriceLevel
# MobileNumbers
# UserAccountIds
# DBName
# ThisYearBeg
# ThisYearEnd
# PrevYearBeg
# PrevYearEnd
# ThisQuarterBeg
# ThisQuarterEnd
# PrevQuarterBeg
# PrevQuarterEnd
# Name
# Address1
# Address2
# Address3
# Address4
# Address5
#
#
# CompanyOperationsInv
# >> Columns in CompanyOperationsInv:
# Name
# StartingFrom
# BooksFrom
# VatApplDate
# ...
# GratuityMonthDays
# GratuityLimitMonths
# CalculationBasis
# RoundingLimit
# AbatementPercentage
# TDSDeducteeSpecialRate
# BeneficiaryCodeMaxLength
# eChequePrintLocationVersion
# eChequePayableLocationVersion
# eDDPrintLocationVersion
# eDDPayableLocationVersion
# PayInsRunningFileNum
# TransactionTypeVersion
# PayInsFileNumLength
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# OpeningBalance
# CreditLimit
# GratuityLimitAmount
# ODLimit
# tempGSTCGSTRate
# tempGSTSGSTRate
# tempGSTIGSTRate
# tempGSTStateCessRate
# tempIsVATfieldsEdited
# tempApplDate
# tempClassification
# tempNature
# tempPartyEntity
# tempBusinessNature
# tempVATRate
# tempAddlTax
# tempCessOnVat
# tempTaxType
# tempMajorCommodityName
# tempCommodityName
# tempCommodityCode
# tempSubCommodityCode
# tempUOM
# tempTypeofGoods
# tempTradeName
# tempGoodsNature
# tempSchedule
# tempScheduleslNo
# tempIsInvDetailsEnable
# tempLocalVATRate
# tempValuationType
# tempIsCalcOnQty
# tempIsSaletoLocalCitizen
# LEDIsTDSApplicableCurrLiab
# IsProductCodeEdited
# PartyoldTempGSTIN
# Address
# MailingName
# TargetRemoteId
# AddressNative
# BankUserLoginID
# OldAuditEntryIds
# ClosingBalance
# Address1
# Address2
# Address3
# Address4
# Address5
# PrimaryGroup
# OverdueBills
# OnAccountValue
# CashInFlow
# CashOutFlow
# Performance
# DrInterest
# CrInterest
# LastInterestDate
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# TNetTDSExpenseLedger
# >> Columns in TNetTDSExpenseLedger:
# StartingFrom
# STRegDate
# LBTRegnDate
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# CreatedDate
# AlteredOn
# VATApplicableDate
# ExciseRegistrationDate
# PANApplicableFrom
# PayInsRunningFileDate
# VATTaxExemptionDate
# Name
# Address
# GUID
# CurrencyName
# EMail
# PriorStateName
# PINCode
# Website
# IncomeTaxNumber
# SalesTaxNumber
# InterStateSTNumber
# VATTINNumber
# CountryName
# ExciseRange
# ExciseDivision
# ExciseCommissionerate
# LBTRegnNo
# LBTZone
# ExportImportCode
# GSTRegistrationType
# VATDealerType
# StateName
# PriceLevel
# UploadLastRefresh
# Parent
# MailingName
# SamplingMethod
# SamplingStrOneFactor
# IFSCode
# Narration
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# GrpDebitParent
# GrpCreditParent
# SysDebitParent
# SysCreditParent
# TDSApplicable
# TCSApplicable
# GSTApplicable
# CreatedBy
# AlteredBy
# TaxClassificationName
# TaxType
# BillCreditPeriod
# BankDetails
# BankBranchName
# BankBSRCode
# DeducteeType
# BusinessType
# TypeOfNotification
# MSMERegNumber
# CountryofResidence
# RelatedPartyId
# RelPartyIssuingAuthority
# ImporterExporterCode
# EmailCC
# Description
# LedAddlAllocType
# TransporterId
# LedgerPhone
# LedgerFax
# LedgerContact
# LedgerMobile
# RelationType
# MailingNameNative
# AddressNative
# StateNameNative
# CountryNameNative
# BasicTypeOfDuty
# GSTType
# ExemptionType
# AppropriateFor
# SubTaxType
# STXNatureOfParty
# NameOnPAN
# UsedForTaxType
# eCommMerchantID
# PartyGSTIN
# GSTDutyHead
# GSTAppropriateTo
# GSTTypeofSupply
# GSTNatureofSupply
# CessValuationMethod
# PartyOldGSTIN
# LedStateName
# PayType
# PayslipName
# AttendanceType
# LeaveType
# CalculationPeriod
# RoundingMethod
# ComputationType
# CalculationType
# PayStatType
# ProfessionalTaxNumber
# UserDefinedCalenderType
# ITNature
# ITComponent
# NotificationNumber
# RegistrationNumber
# ServiceCategory
# AbatementNotificationNo
# STXDutyHead
# STXClassification
# NotificationSlNo
# ServiceTaxApplicable
# ExciseLedgerClassification
# ExciseRegistrationNumber
# ExciseAccountHead
# ExciseDutyType
# ExciseDutyHeadCode
# ExciseAllocType
# ExciseDutyHead
# NatureOfSales
# ExciseNotificationNo
# ExciseImportsRegistartionNo
# ExciseApplicability
# ExciseTypeofBranch
# ExciseDefaultRemoval
# ExciseNotificationSlNo
# TypeOfTariff
# ExciseRegNo
# ExciseNatureofPurchase
# TDSDeducteeTypeMst
# TDSRateName
# TDSDeducteeSectionNumber
# PANStatus
# DeducteeReference
# TDSDeducteeType
# ITExemptApplicable
# TaxIdentificationNo
# LedgerFBTCategory
# BranchCode
# ClientCode
# BankingConfigBank
# BankingConfigBankID
# BankAccHolderName
# UseForPOSType
# PaymentGateway
# TypeOfInterestOn
# BankConfigIFSC
# BankConfigMICR
# BankConfigShortCode
# PymtInstoutputName
# ProductCodeType
# SalaryPymtProductCode
# OtherPymtProductCode
# PaymentInstLocation
# EncrptionLocation
# NewIMFLocation
# ImportedIMFLocation
# BankNewStatements
# BankImportedStatements
# BankMICR
# CorporateUserNoECS
# CorporateUserNoACH
# CorporateUserName
# BankUserLoginID
# IMFName
# PayInsBatchName
# LastUsedBatchName
# PayInsFileNumPeriod
# EncryptedBy
# EncryptedId
# ISOCurrencyCode
# BankCapsuleID
# SalesTaxCessApplicable
# BankIBAN
# VATTaxExemptionNature
# VATTaxExemptionNumber
# VATApplicable
# PartyBusinessType
# PartyBusinessStyle
# SwiftCode
# IsBillWiseOn
# IsCostCentresOn
# IsInterestOn
# AllowinMobile
# IsCostTrackingOn
# IsBeneficiaryCodeOn
# PLasIncomeExpense
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsCondensed
# AffectsStock
# IsRateInclusiveVAT
# ForPayroll
# IsABCEnabled
# IsCreditDaysChkOn
# InterestonBillwise
# OverrideInterest
# OverrideAdvInterest
# UseForVAT
# IgnoreTDSExempt
# IsTCSApplicable
# IsTDSApplicable
# IsFBTApplicable
# IsGSTApplicable
# IsExciseApplicable
# IsTDSExpense
# IsEDLIApplicable
# IsRelatedParty
# UseForESIEligibility
# IsInterestInclLastDay
# AppropriateTaxValue
# IsBehaveAsDuty
# InterestInclDayOfAddition
# InterestInclDayOfDeduction
# IsOthTerritoryAssessee
# OverRideCreditLimit
# IsAgainstFormC
# IsChequePrintingEnabled
# IsPayUpLoad
# IsPayBatchOnlySAL
# IsBNFCodeSupported
# AllowExportWithErrors
# ConsiderPurchaseforExport
# IsTransporter
# UseForNotionalITC
# IseCommOperator
# ShowinPayslip
# UseForGratuity
# IsTDSProjected
# ForServiceTax
# IsInputCredit
# IsExempted
# IsAbatementApplicable
# IsSTXParty
# IsSTXNonRealizedType
# IsUsedForCVD
# LedBelongsToNonTaxable
# IsExciseMerchantExporter
# IsPartyExempted
# IsSEZParty
# TDSDeducteeIsSpecialRate
# IseChequeSupported
# IseDDSupported
# HaseChequeDeliveryMode
# HaseChequeDeliveryTo
# HaseChequePrintLocation
# HaseChequePayableLocation
# HaseChequeBankLocation
# HaseDDDeliveryMode
# HaseDDDeliveryTo
# HaseDDPrintLocation
# HaseDDPayableLocation
# HaseDDBankLocation
# IsEBankingEnabled
# IsExportFileEncrypted
# IsBatchEnabled
# IsProductCodeBased
# HaseDDCity
# HaseChequeCity
# IsFileNameFormatSupported
# HasClientCode
# PayInsIsBatchApplicable
# PayInsIsFileNumApp
# IsSalaryTransGroupedForBRS
# IseBankingSupported
# IsSCBUAE
# IsBankStatusApp
# IsSalaryGrouped
# UseForPurchaseTax
# Audited
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# AlterID
# RemoteAlterID
# DefaultLanguage
# OldAuditEntryIds
# RateOfTaxCalculation
# GratuityMonthDays
# GratuityLimitMonths
# CalculationBasis
# RoundingLimit
# AbatementPercentage
# TDSDeducteeSpecialRate
# BeneficiaryCodeMaxLength
# eChequePrintLocationVersion
# eChequePayableLocationVersion
# eDDPrintLocationVersion
# eDDPayableLocationVersion
# PayInsRunningFileNum
# TransactionTypeVersion
# PayInsFileNumLength
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# OpeningBalance
# CreditLimit
# GratuityLimitAmount
# ODLimit
# ClosingBalance
# Address1
# Address2
# Address3
# Address4
# Address5
# PrimaryGroup
# OverdueBills
# OnAccountValue
# CashInFlow
# CashOutFlow
# Performance
# DrInterest
# CrInterest
# LastInterestDate
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# TransferVchStockJrnl
# >> Columns in TransferVchStockJrnl:
# Name
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# Guid
# Parent
# MailingName
# SamplingMethod
# SamplingStrOneFactor
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# BillCreditPeriod
# NatureOfSales
# TaxUnitName
# VchPrintTitle
# VchPrintDecl
# NumberingMethod
# VCHDeviceType
# VCHDeviceNo
# POSMessageLine1
# POSMessageLine2
# ExciseUnitName
# VchPrintAddlDecl
# LBTDeclaration
# POSReturnType
# VCHPrintJurisdiction
# VchPrintBankName
# ExciseBookName
# VchPrintTitleNative
# VchPrintDeclNative
# ContraContra
# PaymentContra
# ReceiptContra
# JournalContra
# CNoteContra
# DNoteContra
# SalesContra
# PurchaseContra
# CreditCstCtr
# DebitCstCtr
# PreviousPurchase
# PreviousSales
# PreviousGodown
# PrevNarration
# LastNumber
# UseZeroEntries
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsDeemedPositive
# AffectsStock
# IsActive
# PreventDuplicates
# PrefillZero
# PrintAfterSave
# FormalReceipt
# IsOptional
# AsMfgJrnl
# EffectiveDate
# CommonNarration
# MultiNarration
# IsTaxInvoice
# UseForPOSInvoice
# UseForExciseTraderInvoice
# UseForExcise
# UseForJobWork
# IsForJobWorkIn
# AllowConsumption
# UseForExciseGoods
# UseForExciseSupplementary
# IsDefaultAllocEnabled
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# Alterid
# RemoteAlterID
# BeginningNumber
# WidthofNumber
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# TargetRemoteId
# TotalVouchers
# CancelledVouchers
#
#
# UniqueStockItem
# >> Columns in UniqueStockItem:
# Name
# ActiveFrom
# ActiveTo
# PriceLevelDate
# Guid
# PriceLevel
# Parent
# Category
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# TDSApplicable
# TCSApplicable
# GSTApplicable
# TaxClassificationName
# Description
# GSTTypeofSupply
# ServiceTaxApplicable
# ExciseApplicability
# SalesTaxCessApplicable
# VATApplicable
# LedgerName
# CostingMethod
# ValuationMethod
# BaseUnits
# AdditionalUnits
# ExciseTaxType
# NatureofItem
# ExciseItemClassification
# OldBasicTariffType
# TCSCategory
# BasicTariffType
# VatCommodity
# EntryTaxCommodity
# VatBaseUnit
# VatTrailUnit
# ReOrderPeriod
# ReOrderRoundType
# MinOrderPeriod
# MinOrderRoundType
# GSTRepUoM
# GSTConvUnit
# IsCostCentresOn
# IsBatchWiseOn
# IsPerishableOn
# IsEntryTaxApplicable
# IsCostTrackingOn
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsRateInclusiveVAT
# IgnorePhysicalDifference
# IgnoreNegativeStock
# TreatSalesasManufactured
# TreatPurchasesasConsumed
# TreatRejectsasScrap
# HasMfgDate
# AllowUseofExpiredItems
# IgnoreBatches
# IgnoreGodowns
# CalcOnMRP
# ExcludeJrnlForValuation
# IsMRPInclOfTax
# IsAddlTaxExempt
# IsSupplementryDutyOn
# GVATIsExciseAppl
# ReOrderAsHigher
# MinOrderAsHigher
# IsExciseCalculateonMRP
# InclusiveTax
# GSTCalcSlabOnMRP
# ModifyMRPRate
# SortPosition
# Alterid
# RemoteAlterID
# Denominator
# Conversion
# RateofMRP
# BasicRateOfExcise
# RateOfEntryTax
# RateOfVAT
# RateofSAT
# VatBaseNo
# VatTrailNo
# VatActualRatio
# ReOrderPeriodLength
# ReOrderRoundLimit
# MinOrderPeriodLength
# MinOrderRoundLimit
# GSTItemUnits
# GSTRepUnits
# OpeningBalance
# OpeningValue
# BasicValue
# BasicQty
# ReorderBase
# MinimumOrderBase
# OpeningRate
# tempGSTCGSTRate
# tempGSTSGSTRate
# tempGSTIGSTRate
# tempGSTStateCessRate
# tempIsVATfieldsEdited
# tempApplDate
# tempClassification
# tempNature
# tempPartyEntity
# tempBusinessNature
# tempVATRate
# tempAddlTax
# tempCessOnVat
# tempTaxType
# tempMajorCommodityName
# tempCommodityName
# tempCommodityCode
# tempSubCommodityCode
# tempUOM
# tempTypeofGoods
# tempTradeName
# tempGoodsNature
# tempSchedule
# tempScheduleslNo
# tempIsInvDetailsEnable
# tempValuationType
# tempIsCalcOnQty
# tempMRPRate
# tempMRPApplDate
# MailingName
# TargetRemoteId
# OldAuditEntryIds
# ClosingBalance
# InwardQuantity
# OutwardQuantity
# ClosingValue
# InwardValue
# OutwardValue
# ClosingRate
# LastSaleDate
# LastSaleParty
# LastSalePrice
# LastSaleQty
# LastPurcDate
# LastPurcParty
# LastPurcPrice
# LastPurcCost
# LastPurcQty
# Consumption
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# VCHStockItem
# >> Columns in VCHStockItem:
# Name
# ActiveFrom
# ActiveTo
# PriceLevelDate
# Guid
# PriceLevel
# Parent
# Category
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# TDSApplicable
# TCSApplicable
# GSTApplicable
# TaxClassificationName
# Description
# GSTTypeofSupply
# ServiceTaxApplicable
# ExciseApplicability
# SalesTaxCessApplicable
# VATApplicable
# LedgerName
# CostingMethod
# ValuationMethod
# BaseUnits
# AdditionalUnits
# ExciseTaxType
# NatureofItem
# ExciseItemClassification
# OldBasicTariffType
# TCSCategory
# BasicTariffType
# VatCommodity
# EntryTaxCommodity
# VatBaseUnit
# VatTrailUnit
# ReOrderPeriod
# ReOrderRoundType
# MinOrderPeriod
# MinOrderRoundType
# GSTRepUoM
# GSTConvUnit
# IsCostCentresOn
# IsBatchWiseOn
# IsPerishableOn
# IsEntryTaxApplicable
# IsCostTrackingOn
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsRateInclusiveVAT
# IgnorePhysicalDifference
# IgnoreNegativeStock
# TreatSalesasManufactured
# TreatPurchasesasConsumed
# TreatRejectsasScrap
# HasMfgDate
# AllowUseofExpiredItems
# IgnoreBatches
# IgnoreGodowns
# CalcOnMRP
# ExcludeJrnlForValuation
# IsMRPInclOfTax
# IsAddlTaxExempt
# IsSupplementryDutyOn
# GVATIsExciseAppl
# ReOrderAsHigher
# MinOrderAsHigher
# IsExciseCalculateonMRP
# InclusiveTax
# GSTCalcSlabOnMRP
# ModifyMRPRate
# SortPosition
# Alterid
# RemoteAlterID
# Denominator
# Conversion
# RateofMRP
# BasicRateOfExcise
# RateOfEntryTax
# RateOfVAT
# RateofSAT
# VatBaseNo
# VatTrailNo
# VatActualRatio
# ReOrderPeriodLength
# ReOrderRoundLimit
# MinOrderPeriodLength
# MinOrderRoundLimit
# GSTItemUnits
# GSTRepUnits
# OpeningBalance
# OpeningValue
# BasicValue
# BasicQty
# ReorderBase
# MinimumOrderBase
# OpeningRate
# tempGSTCGSTRate
# tempGSTSGSTRate
# tempGSTIGSTRate
# tempGSTStateCessRate
# tempIsVATfieldsEdited
# tempApplDate
# tempClassification
# tempNature
# tempPartyEntity
# tempBusinessNature
# tempVATRate
# tempAddlTax
# tempCessOnVat
# tempTaxType
# tempMajorCommodityName
# tempCommodityName
# tempCommodityCode
# tempSubCommodityCode
# tempUOM
# tempTypeofGoods
# tempTradeName
# tempGoodsNature
# tempSchedule
# tempScheduleslNo
# tempIsInvDetailsEnable
# tempValuationType
# tempIsCalcOnQty
# tempMRPRate
# tempMRPApplDate
# MailingName
# TargetRemoteId
# OldAuditEntryIds
# ClosingBalance
# InwardQuantity
# OutwardQuantity
# ClosingValue
# InwardValue
# OutwardValue
# ClosingRate
# LastSaleDate
# LastSaleParty
# LastSalePrice
# LastSaleQty
# LastPurcDate
# LastPurcParty
# LastPurcPrice
# LastPurcCost
# LastPurcQty
# Consumption
# ThisYearBalance
# PrevYearBalance
# ThisQuarterBalance
# PrevQuarterBalance
#
#
# VCHTariffClassification
# >> Columns in VCHTariffClassification:
# Name
# GUID
# RemoteGUID
# RemoteAltGUID
# TargetRemoteId
# RequestorRule
# ScheduleSerialNumber
# VATCommodityCode
# HSN
# Note
# CommodityName
# ScheduleNumber
# UsedFor
# EntryTaxScheduleNumber
# EntryTaxScheduleSerialNumber
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsActive
# SortPosition
# AlterID
# RemoteAlterID
#
#
# VoucherCostCategory
# >> Columns in VoucherCostCategory:
# Name
# ActiveFrom
# ActiveTo
# Guid
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# AffectsStock
# AllocateRevenue
# AllocateNonRevenue
# SortPosition
# Alterid
# RemoteAlterID
# TargetRemoteId
# OpeningBalance
# ClosingBalance
# CreditTotals
# DebitTotals
#
#
# VoucherType
# >> Columns in VoucherType:
# Name
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# Guid
# Parent
# MailingName
# SamplingMethod
# SamplingStrOneFactor
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# BillCreditPeriod
# NatureOfSales
# TaxUnitName
# VchPrintTitle
# VchPrintDecl
# NumberingMethod
# VCHDeviceType
# VCHDeviceNo
# POSMessageLine1
# POSMessageLine2
# ExciseUnitName
# VchPrintAddlDecl
# LBTDeclaration
# POSReturnType
# VCHPrintJurisdiction
# VchPrintBankName
# ExciseBookName
# VchPrintTitleNative
# VchPrintDeclNative
# ContraContra
# PaymentContra
# ReceiptContra
# JournalContra
# CNoteContra
# DNoteContra
# SalesContra
# PurchaseContra
# CreditCstCtr
# DebitCstCtr
# PreviousPurchase
# PreviousSales
# PreviousGodown
# PrevNarration
# LastNumber
# UseZeroEntries
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsDeemedPositive
# AffectsStock
# IsActive
# PreventDuplicates
# PrefillZero
# PrintAfterSave
# FormalReceipt
# IsOptional
# AsMfgJrnl
# EffectiveDate
# CommonNarration
# MultiNarration
# IsTaxInvoice
# UseForPOSInvoice
# UseForExciseTraderInvoice
# UseForExcise
# UseForJobWork
# IsForJobWorkIn
# AllowConsumption
# UseForExciseGoods
# UseForExciseSupplementary
# IsDefaultAllocEnabled
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# Alterid
# RemoteAlterID
# BeginningNumber
# WidthofNumber
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# TargetRemoteId
# TotalVouchers
# CancelledVouchers
#
#
# VoucherTypePSR
# >> Columns in VoucherTypePSR:
# Name
# SamplingDateOneFactor
# SamplingDateTwoFactor
# ActiveFrom
# ActiveTo
# Guid
# Parent
# MailingName
# SamplingMethod
# SamplingStrOneFactor
# Narration
# RemoteGUID
# RemoteAltGUID
# RequestorRule
# BillCreditPeriod
# NatureOfSales
# TaxUnitName
# VchPrintTitle
# VchPrintDecl
# NumberingMethod
# VCHDeviceType
# VCHDeviceNo
# POSMessageLine1
# POSMessageLine2
# ExciseUnitName
# VchPrintAddlDecl
# LBTDeclaration
# POSReturnType
# VCHPrintJurisdiction
# VchPrintBankName
# ExciseBookName
# VchPrintTitleNative
# VchPrintDeclNative
# ContraContra
# PaymentContra
# ReceiptContra
# JournalContra
# CNoteContra
# DNoteContra
# SalesContra
# PurchaseContra
# CreditCstCtr
# DebitCstCtr
# PreviousPurchase
# PreviousSales
# PreviousGodown
# PrevNarration
# LastNumber
# UseZeroEntries
# IsMstFromSync
# IsUpdatingTargetId
# AsOriginal
# IsDeemedPositive
# AffectsStock
# IsActive
# PreventDuplicates
# PrefillZero
# PrintAfterSave
# FormalReceipt
# IsOptional
# AsMfgJrnl
# EffectiveDate
# CommonNarration
# MultiNarration
# IsTaxInvoice
# UseForPOSInvoice
# UseForExciseTraderInvoice
# UseForExcise
# UseForJobWork
# IsForJobWorkIn
# AllowConsumption
# UseForExciseGoods
# UseForExciseSupplementary
# IsDefaultAllocEnabled
# SamplingNumOneFactor
# SamplingNumTwoFactor
# SortPosition
# Alterid
# RemoteAlterID
# BeginningNumber
# WidthofNumber
# SamplingAmtOneFactor
# SamplingAmtTwoFactor
# TargetRemoteId
# TotalVouchers
# CancelledVouchers

# %%
# Detailed description of columns in a table
cur.execute("SELECT * FROM sys_tablecolumns WHERE TableName = 'Ledger'")
rs = cur.fetchall()
print('\nLedger columns:')
for row in rs:
    print(row)
# Out:
# Ledger columns:
# ('CData', 'Tally', 'Ledger', 'Name', '16', 'varchar', 511, 511, 0, True, None, 0, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'StartingFrom', '5', 'date', 10, 10, 0, True, None, 1, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'STRegDate', '5', 'date', 10, 10, 0, True, None, 2, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LBTRegnDate', '5', 'date', 10, 10, 0, True, None, 3, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingDateOneFactor', '5', 'date', 10, 10, 0, True, None, 4, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingDateTwoFactor', '5', 'date', 10, 10, 0, True, None, 5, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ActiveFrom', '5', 'date', 10, 10, 0, True, None, 6, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ActiveTo', '5', 'date', 10, 10, 0, True, None, 7, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CreatedDate', '5', 'date', 10, 10, 0, True, None, 8, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AlteredOn', '5', 'date', 10, 10, 0, True, None, 9, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATApplicableDate', '5', 'date', 10, 10, 0, True, None, 10, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseRegistrationDate', '5', 'date', 10, 10, 0, True, None, 11, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PANApplicableFrom', '5', 'date', 10, 10, 0, True, None, 12, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsRunningFileDate', '5', 'date', 10, 10, 0, True, None, 13, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATTaxExemptionDate', '5', 'date', 10, 10, 0, True, None, 14, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Guid', '16', 'varchar', 511, 511, 0, True, None, 15, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CurrencyName', '16', 'varchar', 511, 511, 0, True, None, 16, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Email', '16', 'varchar', 511, 511, 0, True, None, 17, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PriorStateName', '16', 'varchar', 511, 511, 0, True, None, 18, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PINCode', '16', 'varchar', 511, 511, 0, True, None, 19, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Website', '16', 'varchar', 511, 511, 0, True, None, 20, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IncomeTaxNumber', '16', 'varchar', 511, 511, 0, True, None, 21, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SalesTaxNumber', '16', 'varchar', 511, 511, 0, True, None, 22, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'InterStateSTNumber', '16', 'varchar', 511, 511, 0, True, None, 23, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATTINNumber', '16', 'varchar', 511, 511, 0, True, None, 24, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CountryName', '16', 'varchar', 511, 511, 0, True, None, 25, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseRange', '16', 'varchar', 511, 511, 0, True, None, 26, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseDivision', '16', 'varchar', 511, 511, 0, True, None, 27, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseCommissionerate', '16', 'varchar', 511, 511, 0, True, None, 28, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LBTRegnNo', '16', 'varchar', 511, 511, 0, True, None, 29, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LBTZone', '16', 'varchar', 511, 511, 0, True, None, 30, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExportImportCode', '16', 'varchar', 511, 511, 0, True, None, 31, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTRegistrationType', '16', 'varchar', 511, 511, 0, True, None, 32, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATDealerType', '16', 'varchar', 511, 511, 0, True, None, 33, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'StateName', '16', 'varchar', 511, 511, 0, True, None, 34, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PriceLevel', '16', 'varchar', 511, 511, 0, True, None, 35, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UploadLastRefresh', '16', 'varchar', 511, 511, 0, True, None, 36, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Parent', '16', 'varchar', 511, 511, 0, True, None, 37, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingMethod', '16', 'varchar', 511, 511, 0, True, None, 38, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingStrOneFactor', '16', 'varchar', 511, 511, 0, True, None, 39, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IFSCode', '16', 'varchar', 511, 511, 0, True, None, 40, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Narration', '16', 'varchar', 511, 511, 0, True, None, 41, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RemoteGUID', '16', 'varchar', 511, 511, 0, True, None, 42, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RemoteAltGUID', '16', 'varchar', 511, 511, 0, True, None, 43, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RequestorRule', '16', 'varchar', 511, 511, 0, True, None, 44, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GrpDebitParent', '16', 'varchar', 511, 511, 0, True, None, 45, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GrpCreditParent', '16', 'varchar', 511, 511, 0, True, None, 46, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SysDebitParent', '16', 'varchar', 511, 511, 0, True, None, 47, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SysCreditParent', '16', 'varchar', 511, 511, 0, True, None, 48, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSApplicable', '16', 'varchar', 511, 511, 0, True, None, 49, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TCSApplicable', '16', 'varchar', 511, 511, 0, True, None, 50, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTApplicable', '16', 'varchar', 511, 511, 0, True, None, 51, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CreatedBy', '16', 'varchar', 511, 511, 0, True, None, 52, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AlteredBy', '16', 'varchar', 511, 511, 0, True, None, 53, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TaxClassificationName', '16', 'varchar', 511, 511, 0, True, None, 54, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TaxType', '16', 'varchar', 511, 511, 0, True, None, 55, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BillCreditPeriod', '16', 'varchar', 511, 511, 0, True, None, 56, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankDetails', '16', 'varchar', 511, 511, 0, True, None, 57, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankBranchName', '16', 'varchar', 511, 511, 0, True, None, 58, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankBSRCode', '16', 'varchar', 511, 511, 0, True, None, 59, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'DeducteeType', '16', 'varchar', 511, 511, 0, True, None, 60, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BusinessType', '16', 'varchar', 511, 511, 0, True, None, 61, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TypeOfNotification', '16', 'varchar', 511, 511, 0, True, None, 62, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'MSMERegNumber', '16', 'varchar', 511, 511, 0, True, None, 63, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CountryofResidence', '16', 'varchar', 511, 511, 0, True, None, 64, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RelatedPartyId', '16', 'varchar', 511, 511, 0, True, None, 65, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RelPartyIssuingAuthority', '16', 'varchar', 511, 511, 0, True, None, 66, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ImporterExporterCode', '16', 'varchar', 511, 511, 0, True, None, 67, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'EMailCC', '16', 'varchar', 511, 511, 0, True, None, 68, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Description', '16', 'varchar', 511, 511, 0, True, None, 69, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedAddlAllocType', '16', 'varchar', 511, 511, 0, True, None, 70, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TransporterId', '16', 'varchar', 511, 511, 0, True, None, 71, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedgerPhone', '16', 'varchar', 511, 511, 0, True, None, 72, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedgerFax', '16', 'varchar', 511, 511, 0, True, None, 73, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedgerContact', '16', 'varchar', 511, 511, 0, True, None, 74, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedgerMobile', '16', 'varchar', 511, 511, 0, True, None, 75, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RelationType', '16', 'varchar', 511, 511, 0, True, None, 76, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'MailingNameNative', '16', 'varchar', 511, 511, 0, True, None, 77, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'StateNameNative', '16', 'varchar', 511, 511, 0, True, None, 78, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CountryNameNative', '16', 'varchar', 511, 511, 0, True, None, 79, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BasicTypeOfDuty', '16', 'varchar', 511, 511, 0, True, None, 80, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTType', '16', 'varchar', 511, 511, 0, True, None, 81, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExemptionType', '16', 'varchar', 511, 511, 0, True, None, 82, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AppropriateFor', '16', 'varchar', 511, 511, 0, True, None, 83, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SubTaxType', '16', 'varchar', 511, 511, 0, True, None, 84, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'STXNatureOfParty', '16', 'varchar', 511, 511, 0, True, None, 85, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'NameOnPAN', '16', 'varchar', 511, 511, 0, True, None, 86, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UsedForTaxType', '16', 'varchar', 511, 511, 0, True, None, 87, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'eCommMerchantID', '16', 'varchar', 511, 511, 0, True, None, 88, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PartyGSTIN', '16', 'varchar', 511, 511, 0, True, None, 89, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTDutyHead', '16', 'varchar', 511, 511, 0, True, None, 90, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTAppropriateTo', '16', 'varchar', 511, 511, 0, True, None, 91, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTTypeofSupply', '16', 'varchar', 511, 511, 0, True, None, 92, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GSTNatureofSupply', '16', 'varchar', 511, 511, 0, True, None, 93, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CessValuationMethod', '16', 'varchar', 511, 511, 0, True, None, 94, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PartyoldGSTIN', '16', 'varchar', 511, 511, 0, True, None, 95, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedStateName', '16', 'varchar', 511, 511, 0, True, None, 96, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayType', '16', 'varchar', 511, 511, 0, True, None, 97, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayslipName', '16', 'varchar', 511, 511, 0, True, None, 98, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AttendanceType', '16', 'varchar', 511, 511, 0, True, None, 99, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LeaveType', '16', 'varchar', 511, 511, 0, True, None, 100, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CalculationPeriod', '16', 'varchar', 511, 511, 0, True, None, 101, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RoundingMethod', '16', 'varchar', 511, 511, 0, True, None, 102, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ComputationType', '16', 'varchar', 511, 511, 0, True, None, 103, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CalculationType', '16', 'varchar', 511, 511, 0, True, None, 104, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayStatType', '16', 'varchar', 511, 511, 0, True, None, 105, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ProfessionalTaxNumber', '16', 'varchar', 511, 511, 0, True, None, 106, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UserDefinedCalenderType', '16', 'varchar', 511, 511, 0, True, None, 107, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ITNature', '16', 'varchar', 511, 511, 0, True, None, 108, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ITComponent', '16', 'varchar', 511, 511, 0, True, None, 109, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'NotificationNumber', '16', 'varchar', 511, 511, 0, True, None, 110, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'RegistrationNumber', '16', 'varchar', 511, 511, 0, True, None, 111, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ServiceCategory', '16', 'varchar', 511, 511, 0, True, None, 112, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AbatementNotificationNo', '16', 'varchar', 511, 511, 0, True, None, 113, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'STXDutyHead', '16', 'varchar', 511, 511, 0, True, None, 114, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'STXClassification', '16', 'varchar', 511, 511, 0, True, None, 115, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'NotificationSlNo', '16', 'varchar', 511, 511, 0, True, None, 116, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ServiceTaxApplicable', '16', 'varchar', 511, 511, 0, True, None, 117, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseLedgerClassification', '16', 'varchar', 511, 511, 0, True, None, 118, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseRegistrationNumber', '16', 'varchar', 511, 511, 0, True, None, 119, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseAccountHead', '16', 'varchar', 511, 511, 0, True, None, 120, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseDutyType', '16', 'varchar', 511, 511, 0, True, None, 121, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseDutyHeadCode', '16', 'varchar', 511, 511, 0, True, None, 122, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseAllocType', '16', 'varchar', 511, 511, 0, True, None, 123, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseDutyHead', '16', 'varchar', 511, 511, 0, True, None, 124, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'NatureOfSales', '16', 'varchar', 511, 511, 0, True, None, 125, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseNotificationNo', '16', 'varchar', 511, 511, 0, True, None, 126, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseImportsRegistartionNo', '16', 'varchar', 511, 511, 0, True, None, 127, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseApplicability', '16', 'varchar', 511, 511, 0, True, None, 128, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseTypeofBranch', '16', 'varchar', 511, 511, 0, True, None, 129, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseDefaultRemoval', '16', 'varchar', 511, 511, 0, True, None, 130, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseNotificationSlNo', '16', 'varchar', 511, 511, 0, True, None, 131, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TypeOfTariff', '16', 'varchar', 511, 511, 0, True, None, 132, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseRegNo', '16', 'varchar', 511, 511, 0, True, None, 133, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ExciseNatureofPurchase', '16', 'varchar', 511, 511, 0, True, None, 134, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSDeducteeTypeMst', '16', 'varchar', 511, 511, 0, True, None, 135, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TdsRateName', '16', 'varchar', 511, 511, 0, True, None, 136, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSDeducteeSectionNumber', '16', 'varchar', 511, 511, 0, True, None, 137, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PANStatus', '16', 'varchar', 511, 511, 0, True, None, 138, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'DeducteeReference', '16', 'varchar', 511, 511, 0, True, None, 139, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSDeducteeType', '16', 'varchar', 511, 511, 0, True, None, 140, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ITExemptApplicable', '16', 'varchar', 511, 511, 0, True, None, 141, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TaxIdentificationNo', '16', 'varchar', 511, 511, 0, True, None, 142, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedgerFBTCategory', '16', 'varchar', 511, 511, 0, True, None, 143, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BranchCode', '16', 'varchar', 511, 511, 0, True, None, 144, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ClientCode', '16', 'varchar', 511, 511, 0, True, None, 145, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankingConfigBank', '16', 'varchar', 511, 511, 0, True, None, 146, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankingConfigBankId', '16', 'varchar', 511, 511, 0, True, None, 147, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankAccHolderName', '16', 'varchar', 511, 511, 0, True, None, 148, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForPOSType', '16', 'varchar', 511, 511, 0, True, None, 149, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PaymentGateway', '16', 'varchar', 511, 511, 0, True, None, 150, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TypeOfInterestOn', '16', 'varchar', 511, 511, 0, True, None, 151, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankConfigIFSC', '16', 'varchar', 511, 511, 0, True, None, 152, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankConfigMICR', '16', 'varchar', 511, 511, 0, True, None, 153, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankConfigShortCode', '16', 'varchar', 511, 511, 0, True, None, 154, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PymtInstoutputName', '16', 'varchar', 511, 511, 0, True, None, 155, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ProductCodeType', '16', 'varchar', 511, 511, 0, True, None, 156, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SalaryPymtProductCode', '16', 'varchar', 511, 511, 0, True, None, 157, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OtherPymtProductCode', '16', 'varchar', 511, 511, 0, True, None, 158, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PaymentInstLocation', '16', 'varchar', 511, 511, 0, True, None, 159, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'EncrptionLocation', '16', 'varchar', 511, 511, 0, True, None, 160, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'NewIMFLocation', '16', 'varchar', 511, 511, 0, True, None, 161, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ImportedIMFLocation', '16', 'varchar', 511, 511, 0, True, None, 162, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankNewStatements', '16', 'varchar', 511, 511, 0, True, None, 163, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankImportedStatements', '16', 'varchar', 511, 511, 0, True, None, 164, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankMICR', '16', 'varchar', 511, 511, 0, True, None, 165, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CorporateUserNoECS', '16', 'varchar', 511, 511, 0, True, None, 166, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CorporateUserNoACH', '16', 'varchar', 511, 511, 0, True, None, 167, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CorporateUserName', '16', 'varchar', 511, 511, 0, True, None, 168, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IMFName', '16', 'varchar', 511, 511, 0, True, None, 169, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsBatchName', '16', 'varchar', 511, 511, 0, True, None, 170, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LastUsedBatchName', '16', 'varchar', 511, 511, 0, True, None, 171, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsFileNumPeriod', '16', 'varchar', 511, 511, 0, True, None, 172, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'EncryptedBy', '16', 'varchar', 511, 511, 0, True, None, 173, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'EncryptedId', '16', 'varchar', 511, 511, 0, True, None, 174, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ISOCurrencyCode', '16', 'varchar', 511, 511, 0, True, None, 175, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankCapsuleID', '16', 'varchar', 511, 511, 0, True, None, 176, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SalesTaxCessApplicable', '16', 'varchar', 511, 511, 0, True, None, 177, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankIBAN', '16', 'varchar', 511, 511, 0, True, None, 178, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATTaxExemptionNature', '16', 'varchar', 511, 511, 0, True, None, 179, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATTaxExemptionNumber', '16', 'varchar', 511, 511, 0, True, None, 180, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'VATApplicable', '16', 'varchar', 511, 511, 0, True, None, 181, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PartyBusinessType', '16', 'varchar', 511, 511, 0, True, None, 182, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PartyBusinessStyle', '16', 'varchar', 511, 511, 0, True, None, 183, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SwiftCode', '16', 'varchar', 511, 511, 0, True, None, 184, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBillWiseOn', '16', 'varchar', 511, 511, 0, True, None, 185, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsCostCentresOn', '16', 'varchar', 511, 511, 0, True, None, 186, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsInterestOn', '16', 'varchar', 511, 511, 0, True, None, 187, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AllowinMobile', '16', 'varchar', 511, 511, 0, True, None, 188, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsCostTrackingOn', '16', 'varchar', 511, 511, 0, True, None, 189, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBeneficiaryCodeOn', '16', 'varchar', 511, 511, 0, True, None, 190, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PLasIncomeExpense', '16', 'varchar', 511, 511, 0, True, None, 191, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsMstFromSync', '16', 'varchar', 511, 511, 0, True, None, 192, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsUpdatingTargetId', '16', 'varchar', 511, 511, 0, True, None, 193, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AsOriginal', '16', 'varchar', 511, 511, 0, True, None, 194, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsCondensed', '16', 'varchar', 511, 511, 0, True, None, 195, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AffectsStock', '16', 'varchar', 511, 511, 0, True, None, 196, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsRateInclusiveVAT', '16', 'varchar', 511, 511, 0, True, None, 197, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ForPayroll', '16', 'varchar', 511, 511, 0, True, None, 198, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsABCEnabled', '16', 'varchar', 511, 511, 0, True, None, 199, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsCreditDaysChkOn', '16', 'varchar', 511, 511, 0, True, None, 200, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'InterestonBillwise', '16', 'varchar', 511, 511, 0, True, None, 201, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OverrideInterest', '16', 'varchar', 511, 511, 0, True, None, 202, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OverrideAdvInterest', '16', 'varchar', 511, 511, 0, True, None, 203, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForVAT', '16', 'varchar', 511, 511, 0, True, None, 204, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IgnoreTDSExempt', '16', 'varchar', 511, 511, 0, True, None, 205, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsTCSApplicable', '16', 'varchar', 511, 511, 0, True, None, 206, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsTDSApplicable', '16', 'varchar', 511, 511, 0, True, None, 207, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsFBTApplicable', '16', 'varchar', 511, 511, 0, True, None, 208, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsGSTApplicable', '16', 'varchar', 511, 511, 0, True, None, 209, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsExciseApplicable', '16', 'varchar', 511, 511, 0, True, None, 210, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsTDSExpense', '16', 'varchar', 511, 511, 0, True, None, 211, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsEDLIApplicable', '16', 'varchar', 511, 511, 0, True, None, 212, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsRelatedParty', '16', 'varchar', 511, 511, 0, True, None, 213, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForESIEligibility', '16', 'varchar', 511, 511, 0, True, None, 214, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsInterestInclLastDay', '16', 'varchar', 511, 511, 0, True, None, 215, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AppropriateTaxValue', '16', 'varchar', 511, 511, 0, True, None, 216, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBehaveAsDuty', '16', 'varchar', 511, 511, 0, True, None, 217, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'InterestInclDayOfAddition', '16', 'varchar', 511, 511, 0, True, None, 218, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'InterestInclDayOfDeduction', '16', 'varchar', 511, 511, 0, True, None, 219, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsOthTerritoryAssessee', '16', 'varchar', 511, 511, 0, True, None, 220, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OverRideCreditLimit', '16', 'varchar', 511, 511, 0, True, None, 221, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsAgainstFormC', '16', 'varchar', 511, 511, 0, True, None, 222, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsChequePrintingEnabled', '16', 'varchar', 511, 511, 0, True, None, 223, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsPayUpLoad', '16', 'varchar', 511, 511, 0, True, None, 224, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsPayBatchOnlySAL', '16', 'varchar', 511, 511, 0, True, None, 225, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBNFCodeSupported', '16', 'varchar', 511, 511, 0, True, None, 226, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AllowExportWithErrors', '16', 'varchar', 511, 511, 0, True, None, 227, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ConsiderPurchaseforExport', '16', 'varchar', 511, 511, 0, True, None, 228, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsTransporter', '16', 'varchar', 511, 511, 0, True, None, 229, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForNotionalITC', '16', 'varchar', 511, 511, 0, True, None, 230, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IseCommOperator', '16', 'varchar', 511, 511, 0, True, None, 231, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ShowInPayslip', '16', 'varchar', 511, 511, 0, True, None, 232, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForGratuity', '16', 'varchar', 511, 511, 0, True, None, 233, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsTDSProjected', '16', 'varchar', 511, 511, 0, True, None, 234, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ForServiceTax', '16', 'varchar', 511, 511, 0, True, None, 235, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsInputCredit', '16', 'varchar', 511, 511, 0, True, None, 236, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsExempted', '16', 'varchar', 511, 511, 0, True, None, 237, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsAbatementApplicable', '16', 'varchar', 511, 511, 0, True, None, 238, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSTXParty', '16', 'varchar', 511, 511, 0, True, None, 239, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSTXNonRealizedType', '16', 'varchar', 511, 511, 0, True, None, 240, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsUsedForCVD', '16', 'varchar', 511, 511, 0, True, None, 241, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LedBelongsToNonTaxable', '16', 'varchar', 511, 511, 0, True, None, 242, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsExciseMerchantExporter', '16', 'varchar', 511, 511, 0, True, None, 243, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsPartyExempted', '16', 'varchar', 511, 511, 0, True, None, 244, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSEZParty', '16', 'varchar', 511, 511, 0, True, None, 245, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSDeducteeIsSpecialRate', '16', 'varchar', 511, 511, 0, True, None, 246, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IseChequeSupported', '16', 'varchar', 511, 511, 0, True, None, 247, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IseDDSupported', '16', 'varchar', 511, 511, 0, True, None, 248, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequeDeliveryMode', '16', 'varchar', 511, 511, 0, True, None, 249, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequeDeliveryTo', '16', 'varchar', 511, 511, 0, True, None, 250, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequePrintLocation', '16', 'varchar', 511, 511, 0, True, None, 251, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequePayableLocation', '16', 'varchar', 511, 511, 0, True, None, 252, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequeBankLocation', '16', 'varchar', 511, 511, 0, True, None, 253, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDDeliveryMode', '16', 'varchar', 511, 511, 0, True, None, 254, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDDeliveryTo', '16', 'varchar', 511, 511, 0, True, None, 255, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDPrintLocation', '16', 'varchar', 511, 511, 0, True, None, 256, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDPayableLocation', '16', 'varchar', 511, 511, 0, True, None, 257, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDBankLocation', '16', 'varchar', 511, 511, 0, True, None, 258, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IseBankingEnabled', '16', 'varchar', 511, 511, 0, True, None, 259, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsExportFileEncrypted', '16', 'varchar', 511, 511, 0, True, None, 260, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBatchEnabled', '16', 'varchar', 511, 511, 0, True, None, 261, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsProductCodeBased', '16', 'varchar', 511, 511, 0, True, None, 262, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseDDCity', '16', 'varchar', 511, 511, 0, True, None, 263, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HaseChequeCity', '16', 'varchar', 511, 511, 0, True, None, 264, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsFileNameFormatSupported', '16', 'varchar', 511, 511, 0, True, None, 265, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'HasClientCode', '16', 'varchar', 511, 511, 0, True, None, 266, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsIsBatchApplicable', '16', 'varchar', 511, 511, 0, True, None, 267, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsIsFileNumApp', '16', 'varchar', 511, 511, 0, True, None, 268, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSalaryTransGroupedForBRS', '16', 'varchar', 511, 511, 0, True, None, 269, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IseBankingSupported', '16', 'varchar', 511, 511, 0, True, None, 270, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSCBUAE', '16', 'varchar', 511, 511, 0, True, None, 271, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsBankStatusApp', '16', 'varchar', 511, 511, 0, True, None, 272, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsSalaryGrouped', '16', 'varchar', 511, 511, 0, True, None, 273, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'UseForPurchaseTax', '16', 'varchar', 511, 511, 0, True, None, 274, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Audited', '16', 'varchar', 511, 511, 0, True, None, 275, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingNumOneFactor', '7', 'decimal', 17, 30, 2, True, None, 276, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingNumTwoFactor', '7', 'decimal', 17, 30, 2, True, None, 277, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'SortPosition', '7', 'decimal', 17, 30, 2, True, None, 278, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'Alterid', '7', 'decimal', 17, 30, 2, True, None, 279, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'RemoteAlterID', '7', 'decimal', 17, 30, 2, True, None, 280, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'DefaultLanguage', '7', 'decimal', 17, 30, 2, True, None, 281, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'RateofTaxCalculation', '7', 'decimal', 17, 30, 2, True, None, 282, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'GratuityMonthDays', '7', 'decimal', 17, 30, 2, True, None, 283, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'GratuityLimitMonths', '7', 'decimal', 17, 30, 2, True, None, 284, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'CalculationBasis', '7', 'decimal', 17, 30, 2, True, None, 285, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'RoundingLimit', '7', 'decimal', 17, 30, 2, True, None, 286, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'AbatementPercentage', '7', 'decimal', 17, 30, 2, True, None, 287, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'TDSDeducteeSpecialRate', '7', 'decimal', 17, 30, 2, True, None, 288, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'BeneficiaryCodeMaxLength', '7', 'decimal', 17, 30, 2, True, None, 289, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'eChequePrintLocationVersion', '7', 'decimal', 17, 30, 2, True, None, 290, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'eChequePayableLocationVersion', '7', 'decimal', 17, 30, 2, True, None, 291, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'eDDPrintLocationVersion', '7', 'decimal', 17, 30, 2, True, None, 292, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'eDDPayableLocationVersion', '7', 'decimal', 17, 30, 2, True, None, 293, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsRunningFileNum', '7', 'decimal', 17, 30, 2, True, None, 294, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'TransactionTypeVersion', '7', 'decimal', 17, 30, 2, True, None, 295, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'PayInsFileNumLength', '7', 'decimal', 17, 30, 2, True, None, 296, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingAmtOneFactor', '16', 'varchar', 511, 511, 0, True, None, 297, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'SamplingAmtTwoFactor', '16', 'varchar', 511, 511, 0, True, None, 298, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OpeningBalance', '7', 'decimal', 17, 30, 2, True, None, 299, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'CreditLimit', '16', 'varchar', 511, 511, 0, True, None, 300, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'GratuityLimitAmount', '16', 'varchar', 511, 511, 0, True, None, 301, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ODLimit', '16', 'varchar', 511, 511, 0, True, None, 302, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempGSTCGSTRate', '7', 'decimal', 17, 30, 2, True, None, 303, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempGSTSGSTRate', '7', 'decimal', 17, 30, 2, True, None, 304, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempGSTIGSTRate', '7', 'decimal', 17, 30, 2, True, None, 305, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempGSTStateCessRate', '7', 'decimal', 17, 30, 2, True, None, 306, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempIsVATfieldsEdited', '16', 'varchar', 511, 511, 0, True, None, 307, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempApplDate', '5', 'date', 10, 10, 0, True, None, 308, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempClassification', '16', 'varchar', 511, 511, 0, True, None, 309, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempNature', '16', 'varchar', 511, 511, 0, True, None, 310, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempPartyEntity', '16', 'varchar', 511, 511, 0, True, None, 311, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempBusinessNature', '16', 'varchar', 511, 511, 0, True, None, 312, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempVATRate', '7', 'decimal', 17, 30, 2, True, None, 313, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempAddlTax', '7', 'decimal', 17, 30, 2, True, None, 314, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempCessOnVat', '7', 'decimal', 17, 30, 2, True, None, 315, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempTaxType', '16', 'varchar', 511, 511, 0, True, None, 316, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempMajorCommodityName', '16', 'varchar', 511, 511, 0, True, None, 317, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempCommodityName', '16', 'varchar', 511, 511, 0, True, None, 318, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempCommodityCode', '16', 'varchar', 511, 511, 0, True, None, 319, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempSubCommodityCode', '16', 'varchar', 511, 511, 0, True, None, 320, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempUOM', '16', 'varchar', 511, 511, 0, True, None, 321, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempTypeofGoods', '16', 'varchar', 511, 511, 0, True, None, 322, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempTradeName', '16', 'varchar', 511, 511, 0, True, None, 323, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempGoodsNature', '16', 'varchar', 511, 511, 0, True, None, 324, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempSchedule', '16', 'varchar', 511, 511, 0, True, None, 325, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempScheduleslNo', '16', 'varchar', 511, 511, 0, True, None, 326, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempIsInvDetailsEnable', '16', 'varchar', 511, 511, 0, True, None, 327, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempLocalVATRate', '7', 'decimal', 17, 30, 2, True, None, 328, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'tempValuationType', '16', 'varchar', 511, 511, 0, True, None, 329, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempIsCalcOnQty', '16', 'varchar', 511, 511, 0, True, None, 330, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'tempIsSaletoLocalCitizen', '16', 'varchar', 511, 511, 0, True, None, 331, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LEDIsTDSApplicableCurrLiab', '16', 'varchar', 511, 511, 0, True, None, 332, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'IsProductCodeEdited', '16', 'varchar', 511, 511, 0, True, None, 333, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PartyoldTempGSTIN', '16', 'varchar', 511, 511, 0, True, None, 334, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address', '16', 'varchar', 511, 511, 0, True, None, 335, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'MailingName', '16', 'varchar', 511, 511, 0, True, None, 336, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'TargetRemoteId', '16', 'varchar', 511, 511, 0, True, None, 337, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'AddressNative', '16', 'varchar', 511, 511, 0, True, None, 338, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'BankUserLoginID', '16', 'varchar', 511, 511, 0, True, None, 339, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OldAuditEntryIds', '7', 'decimal', 17, 30, 2, True, None, 340, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'ClosingBalance', '16', 'varchar', 511, 511, 0, True, None, 341, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address1', '16', 'varchar', 511, 511, 0, True, None, 342, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address2', '16', 'varchar', 511, 511, 0, True, None, 343, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address3', '16', 'varchar', 511, 511, 0, True, None, 344, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address4', '16', 'varchar', 511, 511, 0, True, None, 345, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Address5', '16', 'varchar', 511, 511, 0, True, None, 346, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PrimaryGroup', '16', 'varchar', 511, 511, 0, True, None, 347, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OverdueBills', '16', 'varchar', 511, 511, 0, True, None, 348, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'OnAccountValue', '16', 'varchar', 511, 511, 0, True, None, 349, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CashInFlow', '16', 'varchar', 511, 511, 0, True, None, 350, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'CashOutFlow', '16', 'varchar', 511, 511, 0, True, None, 351, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'Performance', '7', 'decimal', 17, 30, 2, True, None, 352, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'DrInterest', '7', 'decimal', 17, 30, 2, True, None, 353, False, False, False, False, 18, False, False)
# ('CData', 'Tally', 'Ledger', 'CrInterest', '16', 'varchar', 511, 511, 0, True, None, 354, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'LastInterestDate', '5', 'date', 10, 10, 0, True, None, 355, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ThisYearBalance', '16', 'varchar', 511, 511, 0, True, None, 356, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PrevYearBalance', '16', 'varchar', 511, 511, 0, True, None, 357, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'ThisQuarterBalance', '16', 'varchar', 511, 511, 0, True, None, 358, False, False, False, False, 0, False, False)
# ('CData', 'Tally', 'Ledger', 'PrevQuarterBalance', '16', 'varchar', 511, 511, 0, True, None, 359, False, False, False, False, 0, False, False)

# %% [markdown]
# # Reports

# %%
cur = conn.cursor()
#cmd = "EXECUTE ExportData ReportName = ?"
#params = ("Profit and Loss", )
cur.execute("EXECUTE ExportData ReportName = 'Profit and Loss', ExportLocation = 'E:\Clients\TOSBS\Akshay Adamuthe'")
rs = cur.fetchall()
for row in rs:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-119-211c2cd15e09> in <module>
#       3 #params = ("Profit and Loss", )
#       4 cur.execute("EXECUTE ExportData ReportName = 'Profit and Loss', ExportLocation = 'E:\Clients\TOSBS\Akshay Adamuthe'")
# ----> 5 rs = cur.fetchall()
#       6 for row in rs:
#       7     print(row)
#
# ProgrammingError: No results.  Previous SQL was not a DQL.

# %%
cur = conn.cursor()
params = ("Company", )
cur.callproc("CreateSchema", params)
rs = cur.fetchall()
for row in rs:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-110-76aa360d9062> in <module>
#       1 cur = conn.cursor()
#       2 params = ("Company", )
# ----> 3 cur.callproc("CreateSchema", params)
#       4 rs = cur.fetchall()
#       5 for row in rs:
#
# DatabaseError: [500] Could not execute the specified command: Unable to bind the parameter: @1.
